# %% [markdown]
# <a href="https://colab.research.google.com/github/Nikhat24/myprofile/blob/master/iitk_pydata_Nikhat_day04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import numpy as np

# %%
z= pd.Series(['a', 'b', 'c'])  #for creating a series
print(z)
z1= z.reindex(np.arange(0,6))   #first 3 values from z rest all NaN(Not a Number)
print(z1)    #this command is taken because z1.isnull() is the last command if we write only z1 the value of z1 will not printed
z1.isnull()    #returns boolean value of values present(T/F)
# Out:
# 0    a
# 1    b
# 2    c
# dtype: object
# 0    False
# 1    False
# 2    False
# 3     True
# 4     True
# 5     True
# dtype: bool

# %%
frame= pd.DataFrame(np.arange(9).reshape((3,3)), index= ['a','b','c'], columns= ["hey", "hi", "ooooo"])
frame
# Out:
#    hey  hi  ooooo
# a    0   1      2
# b    3   4      5
# c    6   7      8

# %%
frame2 = frame.reindex(['a','b','c','d'])
frame2
# Out:
#    hey   hi  ooooo
# a  0.0  1.0    2.0
# b  3.0  4.0    5.0
# c  6.0  7.0    8.0
# d  NaN  NaN    NaN

# %%
data= pd.DataFrame(np.arange(16).reshape((4,4)), index= ['apple','banana','mango','orange'], columns= ["hey", "hi", "hello", "yo"])
data
# Out:
#         hey  hi  hello  yo
# apple     0   1      2   3
# banana    4   5      6   7
# mango     8   9     10  11
# orange   12  13     14  15

# %%
data.drop(['banana','orange'])
# Out:
#        hey  hi  hello  yo
# apple    0   1      2   3
# mango    8   9     10  11

# %%
data.loc['apple':'mango']     #from apple to mango
# Out:
#         hey  hi  hello  yo
# apple     0   1      2   3
# banana    4   5      6   7
# mango     8   9     10  11

# %%
data.loc['apple':'mango',["hi","yo"]]
# Out:
#         hi  yo
# apple    1   3
# banana   5   7
# mango    9  11

# %%
df1 = pd.DataFrame(np.arange(16).reshape((4,4)), index= ['kanpur','lucknow','delhi','urai'], columns= ["hey", "hi", "hello", "yo"])
df1
# Out:
#          hey  hi  hello  yo
# kanpur     0   1      2   3
# lucknow    4   5      6   7
# delhi      8   9     10  11
# urai      12  13     14  15

# %%
np.exp(df1)
# Out:
#                    hey             hi         hello            yo
# kanpur        1.000000       2.718282  7.389056e+00  2.008554e+01
# lucknow      54.598150     148.413159  4.034288e+02  1.096633e+03
# delhi      2980.957987    8103.083928  2.202647e+04  5.987414e+04
# urai     162754.791419  442413.392009  1.202604e+06  3.269017e+06

# %%
f= lambda x: x.max()-x.min()
df1.apply(f)
# Out:
# hey      12
# hi       12
# hello    12
# yo       12
# dtype: int64

# %%
df1.apply(f, axis="columns")
# Out:
# kanpur     3
# lucknow    3
# delhi      3
# urai       3
# dtype: int64

# %%
df1["hi"].sort_index()
# Out:
# delhi       9
# kanpur      1
# lucknow     5
# urai       13
# Name: hi, dtype: int64

# %%
df1.sort_index()
# Out:
#          hey  hi  hello  yo
# delhi      8   9     10  11
# kanpur     0   1      2   3
# lucknow    4   5      6   7
# urai      12  13     14  15

# %%
df1.describe()
# Out:
#              hey         hi      hello         yo
# count   4.000000   4.000000   4.000000   4.000000
# mean    6.000000   7.000000   8.000000   9.000000
# std     5.163978   5.163978   5.163978   5.163978
# min     0.000000   1.000000   2.000000   3.000000
# 25%     3.000000   4.000000   5.000000   6.000000
# 50%     6.000000   7.000000   8.000000   9.000000
# 75%     9.000000  10.000000  11.000000  12.000000
# max    12.000000  13.000000  14.000000  15.000000

# %%
data= pd.read_csv("https://bit.ly/2UUomN0",sep="\t")    #1
data
data[["item_name", "item_price"]]    #2
# Out:
#                                   item_name item_price
# 0              Chips and Fresh Tomato Salsa     $2.39
# 1                                      Izze     $3.39
# 2                          Nantucket Nectar     $3.39
# 3     Chips and Tomatillo-Green Chili Salsa     $2.39
# 4                              Chicken Bowl    $16.98
# 5                              Chicken Bowl    $10.98
# 6                             Side of Chips     $1.69
# 7                             Steak Burrito    $11.75
# 8                          Steak Soft Tacos     $9.25
# 9                             Steak Burrito     $9.25
# 10                      Chips and Guacamole     $4.45
# 11                     Chicken Crispy Tacos     $8.75
# 12                       Chicken Soft Tacos     $8.75
# 13                             Chicken Bowl    $11.25
# 14                      Chips and Guacamole     $4.45
# 15    Chips and Tomatillo-Green Chili Salsa     $2.39
# ...

# %%
data["item_price"]= data["item_price"].map(lambda x:x.lstrip("$")).astype(np.float)
data["unit_price"]= data["item_price"]/data["quantity"]
data
# Out:
#       order_id  quantity  ... item_price unit_price
# 0            1         1  ...       2.39       2.39
# 1            1         1  ...       3.39       3.39
# 2            1         1  ...       3.39       3.39
# 3            1         1  ...       2.39       2.39
# 4            2         2  ...      16.98       8.49
# 5            3         1  ...      10.98      10.98
# 6            3         1  ...       1.69       1.69
# 7            4         1  ...      11.75      11.75
# 8            4         1  ...       9.25       9.25
# 9            5         1  ...       9.25       9.25
# 10           5         1  ...       4.45       4.45
# 11           6         1  ...       8.75       8.75
# 12           6         1  ...       8.75       8.75
# 13           7         1  ...      11.25      11.25
# 16           8         1  ...       8.49       8.49
# 18           9         2  ...       2.18       1.09
# 19          10         1  ...       8.75       8.75
# ...

# %%
data.groupby("item_name").size()
# Out:
# item_name
# 6 Pack Soft Drink                         2
# Barbacoa Bowl                             6
# Barbacoa Burrito                          6
# Barbacoa Crispy Tacos                     5
# Barbacoa Salad Bowl                       2
# Barbacoa Soft Tacos                       4
# Bottled Water                            10
# Bowl                                      2
# Burrito                                   1
# Canned Soda                               3
# Canned Soft Drink                         4
# Carnitas Bowl                             7
# Carnitas Burrito                          7
# Carnitas Crispy Tacos                     4
# Carnitas Salad                            1
# Carnitas Salad Bowl                       2
# Carnitas Soft Tacos                       3
# Chicken Bowl                             13
# Chicken Burrito                          12
# Chicken Crispy Tacos                      6
# Chicken Salad                             3
# ...

# %%
t=data.groupby("item_name").size()
t["Veggie Salad Bowl"]
# Out:
# 2

# %%
b=data.groupby("item_name").size()
b["Canned Soda"]
# Out:
# 3

# %%
data1= data.drop_duplicates(["item_name", "item_price"])
data1
# Out:
#       order_id  ...  item_price
# 0            1  ...       2.39
# 1            1  ...       3.39
# 2            1  ...       3.39
# 3            1  ...       2.39
# 4            2  ...      16.98
# 5            3  ...      10.98
# 6            3  ...       1.69
# 7            4  ...      11.75
# 8            4  ...       9.25
# 9            5  ...       9.25
# 10           5  ...       4.45
# 11           6  ...       8.75
# 12           6  ...       8.75
# 13           7  ...      11.25
# 16           8  ...       8.49
# 18           9  ...       2.18
# 19          10  ...       8.75
# 21          11  ...       8.99
# 23          12  ...      10.98
# 26          13  ...       8.49
# 27          14  ...       8.99
# 28          14  ...       1.09
# 31          16  ...       8.99
# 33          17  ...       8.99
# 34          17  ...       1.09
# 38          18  ...       2.95
# 39          19  ...      11.75
# 40          19  ...       2.15
# 44          20  ...       8.75
# ...

# %%
data[["item_name", "quantity", "unit_price"]].drop_duplicates(["item_name"]).sort_values(by=["unit_price"]).tail()
# Out:
#                   item_name  quantity  unit_price
# 7             Steak Burrito         1       11.75
# 168   Barbacoa Crispy Tacos         1       11.75
# 1132    Carnitas Salad Bowl         1       11.89
# 1229    Barbacoa Salad Bowl         1       11.89
# 281        Steak Salad Bowl         2       11.89

# %%
pip install openpyxl

# %%
z= pd.Series(['a', 'b', 'c', None])  
print(z)
z.dropna()
#z[z.notnull()]
# Out:
# 0       a
# 1       b
# 2       c
# 3    None
# dtype: object
# 0    a
# 1    b
# 2    c
# dtype: object

# %%
t= pd.read_csv("https://gist.githubusercontent.com/netj/8836201/raw/6f9306ad21398ea43cba4f7d537619d0e07d5ae3/iris.csv",sep=",")
t
s=t.rename(columns= {"sepal.length":"A", "petal.length":"C", "sepal.width":"B", "petal.width":"D"})
s
# Out:
#        A    B    C    D    variety
# 0    5.1  3.5  1.4  0.2     Setosa
# 1    4.9  3.0  1.4  0.2     Setosa
# 2    4.7  3.2  1.3  0.2     Setosa
# 3    4.6  3.1  1.5  0.2     Setosa
# 4    5.0  3.6  1.4  0.2     Setosa
# 5    5.4  3.9  1.7  0.4     Setosa
# 6    4.6  3.4  1.4  0.3     Setosa
# 7    5.0  3.4  1.5  0.2     Setosa
# 8    4.4  2.9  1.4  0.2     Setosa
# 9    4.9  3.1  1.5  0.1     Setosa
# 10   5.4  3.7  1.5  0.2     Setosa
# 11   4.8  3.4  1.6  0.2     Setosa
# 12   4.8  3.0  1.4  0.1     Setosa
# 13   4.3  3.0  1.1  0.1     Setosa
# 14   5.8  4.0  1.2  0.2     Setosa
# 15   5.7  4.4  1.5  0.4     Setosa
# 16   5.4  3.9  1.3  0.4     Setosa
# 17   5.1  3.5  1.4  0.3     Setosa
# 18   5.7  3.8  1.7  0.3     Setosa
# 19   5.1  3.8  1.5  0.3     Setosa
# 20   5.4  3.4  1.7  0.2     Setosa
# 21   5.1  3.7  1.5  0.4     Setosa
# 22   4.6  3.6  1.0  0.2     Setosa
# 23   5.1  3.3  1.7  0.5     Setosa
# 24   4.8  3.4  1.9  0.2     Setosa
# 25   5.0  3.0  1.6  0.2     Setosa
# ...

# %%
s.notnull().sum()
#value    #2
# Out:
# A          150
# B          150
# C          150
# D          150
# variety    150
# dtype: int64

# %%
#s.drop("variety", axis=1, inplace=True)
       
s["C"][9:30]= np.NaN
s
# Out:
#        A    B    C    D
# 0    5.1  3.5  1.4  0.2
# 1    4.9  3.0  1.4  0.2
# 2    4.7  3.2  1.3  0.2
# 3    4.6  3.1  1.5  0.2
# 4    5.0  3.6  1.4  0.2
# 5    5.4  3.9  1.7  0.4
# 6    4.6  3.4  1.4  0.3
# 7    5.0  3.4  1.5  0.2
# 8    4.4  2.9  1.4  0.2
# 9    4.9  3.1  NaN  0.1
# 10   5.4  3.7  NaN  0.2
# 11   4.8  3.4  NaN  0.2
# 12   4.8  3.0  NaN  0.1
# 13   4.3  3.0  NaN  0.1
# 14   5.8  4.0  NaN  0.2
# 15   5.7  4.4  NaN  0.4
# 16   5.4  3.9  NaN  0.4
# 17   5.1  3.5  NaN  0.3
# 18   5.7  3.8  NaN  0.3
# 19   5.1  3.8  NaN  0.3
# 20   5.4  3.4  NaN  0.2
# 21   5.1  3.7  NaN  0.4
# 22   4.6  3.6  NaN  0.2
# 23   5.1  3.3  NaN  0.5
# 24   4.8  3.4  NaN  0.2
# 25   5.0  3.0  NaN  0.2
# 26   5.0  3.4  NaN  0.4
# 27   5.2  3.5  NaN  0.2
# 28   5.2  3.4  NaN  0.2
# 29   4.7  3.2  NaN  0.2
# ..   ...  ...  ...  ...
# 120  6.9  3.2  5.7  2.3
# 121  5.6  2.8  4.9  2.0
# 122  7.7  2.8  6.7  2.0
# 123  6.3  2.7  4.9  1.8
# 124  6.7  3.3  5.7  2.1
# 125  7.2  3.2  6.0  1.8
# ...

# %%
s=s.dropna(how="any")
s
# Out:
#        A    B    C    D
# 0    5.1  3.5  1.4  0.2
# 1    4.9  3.0  1.4  0.2
# 2    4.7  3.2  1.3  0.2
# 3    4.6  3.1  1.5  0.2
# 4    5.0  3.6  1.4  0.2
# 5    5.4  3.9  1.7  0.4
# 6    4.6  3.4  1.4  0.3
# 7    5.0  3.4  1.5  0.2
# 8    4.4  2.9  1.4  0.2
# 30   4.8  3.1  1.6  0.2
# 31   5.4  3.4  1.5  0.4
# 32   5.2  4.1  1.5  0.1
# 33   5.5  4.2  1.4  0.2
# 34   4.9  3.1  1.5  0.2
# 35   5.0  3.2  1.2  0.2
# 36   5.5  3.5  1.3  0.2
# 37   4.9  3.6  1.4  0.1
# 38   4.4  3.0  1.3  0.2
# 39   5.1  3.4  1.5  0.2
# 40   5.0  3.5  1.3  0.3
# 41   4.5  2.3  1.3  0.3
# 42   4.4  3.2  1.3  0.2
# 43   5.0  3.5  1.6  0.6
# 44   5.1  3.8  1.9  0.4
# 45   4.8  3.0  1.4  0.3
# 46   5.1  3.8  1.6  0.2
# 47   4.6  3.2  1.4  0.2
# 48   5.3  3.7  1.5  0.2
# 49   5.0  3.3  1.4  0.2
# 50   7.0  3.2  4.7  1.4
# ..   ...  ...  ...  ...
# 120  6.9  3.2  5.7  2.3
# 121  5.6  2.8  4.9  2.0
# 122  7.7  2.8  6.7  2.0
# 123  6.3  2.7  4.9  1.8
# 124  6.7  3.3  5.7  2.1
# 125  7.2  3.2  6.0  1.8
# ...

# %%
s=s.reset_index(drop=True)
s
# Out:
#        A    B    C    D
# 0    5.1  3.5  1.4  0.2
# 1    4.9  3.0  1.4  0.2
# 2    4.7  3.2  1.3  0.2
# 3    4.6  3.1  1.5  0.2
# 4    5.0  3.6  1.4  0.2
# 5    5.4  3.9  1.7  0.4
# 6    4.6  3.4  1.4  0.3
# 7    5.0  3.4  1.5  0.2
# 8    4.4  2.9  1.4  0.2
# 9    4.8  3.1  1.6  0.2
# 10   5.4  3.4  1.5  0.4
# 11   5.2  4.1  1.5  0.1
# 12   5.5  4.2  1.4  0.2
# 13   4.9  3.1  1.5  0.2
# 14   5.0  3.2  1.2  0.2
# 15   5.5  3.5  1.3  0.2
# 16   4.9  3.6  1.4  0.1
# 17   4.4  3.0  1.3  0.2
# 18   5.1  3.4  1.5  0.2
# 19   5.0  3.5  1.3  0.3
# 20   4.5  2.3  1.3  0.3
# 21   4.4  3.2  1.3  0.2
# 22   5.0  3.5  1.6  0.6
# 23   5.1  3.8  1.9  0.4
# 24   4.8  3.0  1.4  0.3
# 25   5.1  3.8  1.6  0.2
# 26   4.6  3.2  1.4  0.2
# 27   5.3  3.7  1.5  0.2
# 28   5.0  3.3  1.4  0.2
# 29   7.0  3.2  4.7  1.4
# ..   ...  ...  ...  ...
# 99   6.9  3.2  5.7  2.3
# 100  5.6  2.8  4.9  2.0
# 101  7.7  2.8  6.7  2.0
# 102  6.3  2.7  4.9  1.8
# 103  6.7  3.3  5.7  2.1
# 104  7.2  3.2  6.0  1.8
# ...

# %%
g = t.groupby("variety")
g.describe()
# Out:
#            sepal.length                               ... petal.width
#                   count   mean       std  min    25%  ...         min  25%  50%  75%  max
# variety                                               ...
# Setosa             50.0  5.006  0.352490  4.3  4.800  ...         0.1  0.2  0.2  0.3  0.6
# Versicolor         50.0  5.936  0.516171  4.9  5.600  ...         1.0  1.2  1.3  1.5  1.8
# Virginica          50.0  6.588  0.635880  4.9  6.225  ...         1.4  1.8  2.0  2.3  2.5
#
# [3 rows x 32 columns]

# %% [markdown]
# # **Done with TADAAAAAA!!!!!!**

# %%
income= pd.Series(np.random.randint(100000, 100000000, (100000,)))
income.shape
bins= [100000, 3000000, 5000000, 10000000]
cut_arr= pd.cut(income, bins, labels=["low", "med", "high"])
x=cut_arr.head()
# Out:
# 0    high
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# dtype: category
# Categories (3, object): [low < med < high]

# %%
#x= pd.Series([10000, 2000, 1888, 27777, 1555, 2])
x=np.random.randint(50,93, (6))
y=np.random.randint(10,90, (6))
#y= pd.Series([5665, 677, 6667, 7777, 555, 2])
data= pd.DataFrame({"price":x, "units_sold":y}, index= [[2000, 2000, 2002, 2003, 2003, 2004],["A", "B", "C", "D", "E", "F"]], columns= ["price", "units_sold"])
data
# Out:
#         price  units_sold
# 2000 A     69          60
#      B     53          19
# 2002 C     91          82
# 2003 D     69          11
#      E     58          27
# 2004 F     80          57

# %% [markdown]
# # **Matplotlib**

# %%
import matplotlib.pyplot as plt

# %%
data= np.random.randn(200)
plt.plot(data)

# %%
f= plt.figure("My Fig")
ax1= f.add_subplot(2,2,1)
ax2= f.add_subplot(2,2,2)
ax3= f.add_subplot(2,2,3)
ax4= f.add_subplot(2,2,4)
f.show()

ax1.plot(np.random.randn(50).cumsum(),'k--')
ax2.hist(np.random.randn(100), bins=20, color='k', alpha=0.3)
ax3.scatter(np.arange(30), np.arange(30)+3 *np.random.randn(30))
ax4.bar(['A','B','C','D','E'], np.random.randint(20,40,5))
# Out:
# <BarContainer object of 5 artists>

# %%
axes= plt.subplots(4,3)
